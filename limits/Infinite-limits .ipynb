# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
from sympy.abc import x

a,b = np.random.randint(-4,5,2)
c = np.random.choice((-1,1))

expr = sym.expand(c*(x-a)*(x-b)) / \
        sym.expand((x-a)*(x+b))

print(f'Compute the limit as x->{a} of:')
expr
# Out:
# Compute the limit as x->2 of:
# (x**2 - x - 2)/(x**2 - 3*x + 2)

# %%
sym.plot(expr,(x,-10,10),ylim=[-10,10])

# %%
print(f"Limit as x->{a} from the left :{sym.limit(expr,x,a,dir='-')}")
print(f"Limit as x->{a} from the right:{sym.limit(expr,x,a,dir='+')}")
print(f"Two-sided limit as x->{a}     :{sym.limit(expr,x,a,dir='+-')}")
print(f"Function value at x->{a}      :{expr.subs(x,a)}")
# Out:
# Limit as x->2 from the left :3
# Limit as x->2 from the right:3
# Two-sided limit as x->2     :3
# Function value at x->2      :nan

# %%
a = np.random.randint(-4,5)
b = np.random.randint(a,a+5)
c = -sym.sqrt(b-a)

expr = (sym.sqrt(x+b) + c) / (x+a)
print(f'Compute the limit as x->{-a} of:\n')
expr
# Out:
# Compute the limit as x->2 of:
# (sqrt(x + 1) - sqrt(3))/(x - 2)

# %%
sym.plot(expr,(x,-10,10))

# %%
print(f"Limit as x->{-a} from the left :{sym.limit(expr,x,-a,dir='-')}")
print(f"Limit as x->{-a} from the right:{sym.limit(expr,x,-a,dir='+')}")
print(f"Two-sided limit as x->{-a}     :{sym.limit(expr,x,-a,dir='+-')}")
print(f"Function value at x->{-a}      :{expr.subs(x,-a)}")
# Out:
# Limit as x->2 from the left :sqrt(3)/6
# Limit as x->2 from the right:sqrt(3)/6
# Two-sided limit as x->2     :sqrt(3)/6
# Function value at x->2      :nan

# %%
a,b = np.random.randint(-4,5,2)

expr = sym.Abs(x-a) + b
expr = (x-a) /sym.Abs(x-a)

print(f'Compute the limit as x->{a} of :\n')
expr
# Out:
# Compute the limit as x->1 of :
# (x - 1)/Abs(x - 1)

# %%
sym.plot(expr,(x,-10,10))

# %%
print(f"Limit as x->{a} from the left :{sym.limit(expr,x,a,dir='-')}")
print(f"Limit as x->{a} from the right:{sym.limit(expr,x,a,dir='+')}")
print(f"Two-sided limit as x->{a}     :{sym.limit(expr,x,a,dir='+-')}")
print(f"Function value at x->{a}      :{expr.subs(x,a)}")
# Out:
# Limit as x->3 from the left :-1
# Limit as x->3 from the right:1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 print(f"Limit as x->{a} from the left :{sym.limit(expr,x,a,dir='-')}")
#       2 print(f"Limit as x->{a} from the right:{sym.limit(expr,x,a,dir='+')}")
# ----> 3 print(f"Two-sided limit as x->{a}     :{sym.limit(expr,x,a,dir='+-')}")
#       4 print(f"Function value at x->{a}      :{expr.subs(x,a)}")
#
# File ~\anaconda3\Lib\site-packages\sympy\series\limits.py:64, in limit(e, z, z0, dir)
#      13 def limit(e, z, z0, dir="+"):
#      14     """Computes the limit of ``e(z)`` at the point ``z0``.
#      15
#      16     Parameters
#    (...)
#      61      limit_seq : returns the limit of a sequence.
#      62     """
# ---> 64     return Limit(e, z, z0, dir).doit(deep=False)
#
# File ~\anaconda3\Lib\site-packages\sympy\series\limits.py:358, in Limit.doit(self, **hints)
#     356     l = gruntz(e, z, z0, '-')
#     357     if l != r:
# --> 358         raise ValueError("The limit does not exist since "
#     359                 "left hand limit = %s and right hand limit = %s"
#     360                 % (l, r))
#     361 else:
#     362     r = gruntz(e, z, z0, dir)
#
# ValueError: The limit does not exist since left hand limit = -1 and right hand limit = 1
